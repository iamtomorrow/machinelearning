# %%
# Set the color of both the edge and the face to red:
import matplotlib.pyplot as plt 
import numpy as np 

ypoints = np.array([3, 1, 8, 10, 7, 5])

plt.plot(ypoints, marker='o', ms=20, mec='red', mfc='red')
plt.show()
