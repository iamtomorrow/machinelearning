# %%
# Mark each point with a beautiful blue green color:
import matplotlib.pyplot as plt 
import numpy as np 

ypoints = np.array([3, 1, 8, 10, 5, 7])

plt.plot(ypoints, marker='o', ms=20, mec='#25fdfd', mfc='#25fdfd')
plt.show()
